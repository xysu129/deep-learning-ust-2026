# %% [markdown]
# <a href="https://colab.research.google.com/github/xysu129/deep-learning-ust-2026/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
10*2
# Out:
# 20
